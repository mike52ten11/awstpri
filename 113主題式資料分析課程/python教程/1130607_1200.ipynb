# %% [markdown]
# # 一、賦值

# %% [markdown]
# ## 1.文字

# %%
a='hello world'
print(a)
# Out:
# hello world

# %% [markdown]
# ## 2.數字

# %%
a=5
print(a)

# %% [markdown]
# ## 3.陣列

# %% [markdown]
# ### 3.1 字典

# %%
a={'date':'2024-01-01 04:00',
       'name':'tpri',
      'age':18}
print(a)
# Out:
# {'date': '2024-01-01 04:00', 'name': 'tpri', 'age': 18}

# %% [markdown]
# # 二、迴圈

# %%
for i in range(10):
    print(i)
